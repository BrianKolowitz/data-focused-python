# %% [markdown]
# # fhirclient
#
# **Note: this example uses FHIR DSTU3 whereas synthea now supports FHIR R4 so you'll need a different version of the fhirclient library to deal with each dataset**
#
# [fhirclient 3.2.0](https://pypi.org/project/fhirclient/)
#
# The _fhirclient_, a flexible Python client for FHIR servers supporting the SMART on FHIR protocol.
#
# _fhirclient_ versioning is not identical to FHIR versioning, see the full table for reference.
#
# | Version | FHIR | |
# | --- | --- | --- |
# | **4.0.0** | `4.0.0` | (R4) |
# | **3.0.0** | `3.0.0` | (STU-3) |
# | **1.0.3** | `1.0.2` | (DSTU 2) |
# | **1.0** | `1.0.1` | (DSTU 2) |
#
# ## Installation
#
# ```bash
# pip install fhirclient
# ```
#
# or
# ```bash
# pip install git+https://github.com/smart-on-fhir/client-py.git
# ```
#
# ## Documentation
#
# Technical documentation is available at [docs](https://docs.smarthealthit.org/client-py/).

# %% [markdown]
# ## Client Use
#
# To connect to a SMART on FHIR server (or any open FHIR server), you can use the `FHIRClient` class.
# It will initialize and handle a `FHIRServer` instance, your actual handle to the FHIR server you'd like to access.
#
# ### Read Data from Server
#
# To read a given patient from an open FHIR server, you can use:

# %%
from pprint import pprint
from fhirclient import client

settings = {
'app_id': 'my_web_app',
'api_base': 'http://hapi.fhir.org/baseDstu3'
}

smart = client.FHIRClient(settings=settings)

import fhirclient.models.patient as p

patient = p.Patient.read('1693321', smart.server)
print(patient.birthDate.isostring)
print(smart.human_name(patient.name[0]))
# Out:
# 1951-02-15
# Jimmy McNutty

# %% [markdown]
# If this is a protected server, you will first have to send your user to the authorize endpoint to log in.
#
# 1. Call `smart.authorize_url` to obtain the correct URL.
#     2. You can use `smart.prepare()`, which will return `False` if the server is protected and you need to authorize.
#     2. The `smart.ready` property has the same purpose, it will however not retrieve the server's _CapabilityStatement_ resource and hence is only useful as a quick check whether the server instance is ready.

# %%
smart = client.FHIRClient(settings=settings)
smart.ready

# prints False
print(smart.prepare())

# prints True after fetching CapabilityStatement
print(smart.ready)

# prints True
print(smart.prepare())

# prints True immediately
print(smart.authorize_url)
# Out:
# True
# True
# True
# None

# %% [markdown]
# You can work with the `FHIRServer` class directly, without using `FHIRClient`, but this is not recommended:

# %%
import fhirclient.server

smart = fhirclient.server.FHIRServer(None, 'http://hapi.fhir.org/baseDstu3')

import fhirclient.models.patient as p

patient = p.Patient.read('1693321', smart)
patient.name[0].given
# Out:
# ['Jimmy']

# %% [markdown]
# ### Search Records on Server
#
# You can also search for resources matching a particular set of criteria:

# %%
smart = client.FHIRClient(settings=settings)

import fhirclient.models.observation as o

search = o.Observation.where(struct={'subject': 'Patient/1913132'})
observations = search.perform_resources(smart.server)
# print(observations)

for observation in observations:
    pprint(observation.as_json())
# Out:
# {'category': [{'coding': [{'code': 'vital-signs',
#                            'system': 'http://hl7.org/fhir/observation-category'}]}],
#  'code': {'coding': [{'code': '55284-4',
#                       'display': 'Blood Pressure',
#                       'system': 'http://loinc.org'}]},
#  'component': [{'code': {'coding': [{'code': '8480-6',
#                                      'display': 'Systolic Blood Pressure',
#                                      'system': 'http://loinc.org'}],
#                          'text': 'Systolic Blood Pressure'},
#                 'valueQuantity': {'code': 'mmHg',
#                                   'system': 'http://unitsofmeasure.org',
#                                   'unit': 'mmHg',
#                                   'value': 131}},
#                {'code': {'coding': [{'code': '8462-4',
#                                      'display': 'Diastolic Blood Pressure',
#                                      'system': 'http://loinc.org'}],
#                          'text': 'Diastolic Blood Pressure'},
#                 'valueQuantity': {'code': 'mmHg',
#                                   'system': 'http://unitsofmeasure.org',
#                                   'unit': 'mmHg',
#                                   'value': 77}}],
#  'context': {'reference': 'Encounter/1913241'},
#  'effectiveDateTime': '2019-02-10T01:13:13-04:00',
#  'id': '1913246',
#  'issued': '2019-02-10T01:13:13-04:00',
#  'meta': {'lastUpdated': '2019-05-09T10:09:50.460+00:00',
#           'profile': ['http://standardhealthrecord.org/fhir/StructureDefinition/shr-observation-Observation',
#                       'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-BloodPressure'],
#           'versionId': '1'},
#  'resourceType': 'Observation',
#  'status': 'final',
#  'subject': {'reference': 'Patient/1913132'}}
# {'category': [{'coding': [{'code': 'vital-signs',
#                            'system': 'http://hl7.org/fhir/observation-category'}]}],
#  'code': {'coding': [{'code': '39156-5',
#                       'display': 'Body Mass Index',
#                       'system': 'http://loinc.org'}],
#           'text': 'Body Mass Index'},
#  'context': {'reference': 'Encounter/1913241'},
#  'effectiveDateTime': '2019-02-10T01:13:13-04:00',
#  'id': '1913245',
#  'issued': '2019-02-10T01:13:13-04:00',
#  'meta': {'lastUpdated': '2019-05-09T10:09:50.460+00:00',
#           'profile': ['http://standardhealthrecord.org/fhir/StructureDefinition/shr-observation-Observation',
#                       'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-VitalSign',
#                       'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-BodyMassIndex'],
#           'versionId': '1'},
#  'resourceType': 'Observation',
#  'status': 'final',
#  'subject': {'reference': 'Patient/1913132'},
#  'valueQuantity': {'code': 'kg/m2',
#                    'system': 'http://unitsofmeasure.org',
#                    'unit': 'kg/m2',
#                    'value': 38.35790913354118}}
# {'category': [{'coding': [{'code': 'vital-signs',
#                            'system': 'http://hl7.org/fhir/observation-category'}]}],
#  'code': {'coding': [{'code': '29463-7',
#                       'display': 'Body Weight',
#                       'system': 'http://loinc.org'}],
#           'text': 'Body Weight'},
#  'context': {'reference': 'Encounter/1913241'},
#  'effectiveDateTime': '2019-02-10T01:13:13-04:00',
#  'id': '1913244',
#  'issued': '2019-02-10T01:13:13-04:00',
#  'meta': {'lastUpdated': '2019-05-09T10:09:50.460+00:00',
#           'profile': ['http://standardhealthrecord.org/fhir/StructureDefinition/shr-observation-Observation',
#                       'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-VitalSign',
#                       'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-BodyWeight'],
#           'versionId': '1'},
#  'resourceType': 'Observation',
#  'status': 'final',
#  'subject': {'reference': 'Patient/1913132'},
#  'valueQuantity': {'code': 'kg',
#                    'system': 'http://unitsofmeasure.org',
#                    'unit': 'kg',
#                    'value': 114.11381988216317}}
# {'category': [{'coding': [{'code': 'vital-signs',
#                            'system': 'http://hl7.org/fhir/observation-category'}]}],
#  'code': {'coding': [{'code': '8302-2',
#                       'display': 'Body Height',
#                       'system': 'http://loinc.org'}],
#           'text': 'Body Height'},
#  'context': {'reference': 'Encounter/1913241'},
#  'effectiveDateTime': '2019-02-10T01:13:13-04:00',
#  'id': '1913243',
#  'issued': '2019-02-10T01:13:13-04:00',
#  'meta': {'lastUpdated': '2019-05-09T10:09:50.460+00:00',
#           'profile': ['http://standardhealthrecord.org/fhir/StructureDefinition/shr-observation-Observation',
#                       'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-VitalSign',
#                       'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-BodyHeight'],
#           'versionId': '1'},
#  'resourceType': 'Observation',
#  'status': 'final',
#  'subject': {'reference': 'Patient/1913132'},
#  'valueQuantity': {'code': 'cm',
#                    'system': 'http://unitsofmeasure.org',
#                    'unit': 'cm',
#                    'value': 172.4811577546544}}
# {'category': [{'coding': [{'code': 'vital-signs',
#                            'system': 'http://hl7.org/fhir/observation-category'}]}],
#  'code': {'coding': [{'code': '55284-4',
#                       'display': 'Blood Pressure',
#                       'system': 'http://loinc.org'}]},
#  'component': [{'code': {'coding': [{'code': '8480-6',
#                                      'display': 'Systolic Blood Pressure',
#                                      'system': 'http://loinc.org'}],
#                          'text': 'Systolic Blood Pressure'},
#                 'valueQuantity': {'code': 'mmHg',
#                                   'system': 'http://unitsofmeasure.org',
#                                   'unit': 'mmHg',
#                                   'value': 122}},
#                {'code': {'coding': [{'code': '8462-4',
#                                      'display': 'Diastolic Blood Pressure',
#                                      'system': 'http://loinc.org'}],
#                          'text': 'Diastolic Blood Pressure'},
#                 'valueQuantity': {'code': 'mmHg',
#                                   'system': 'http://unitsofmeasure.org',
#                                   'unit': 'mmHg',
#                                   'value': 89}}],
#  'context': {'reference': 'Encounter/1913141'},
#  'effectiveDateTime': '2009-10-04T10:00:59-04:00',
#  'id': '1913146',
#  'issued': '2009-10-04T10:00:59-04:00',
#  'meta': {'lastUpdated': '2019-05-09T10:09:50.460+00:00',
#           'profile': ['http://standardhealthrecord.org/fhir/StructureDefinition/shr-observation-Observation',
#                       'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-BloodPressure'],
#           'versionId': '1'},
#  'resourceType': 'Observation',
#  'status': 'final',
#  'subject': {'reference': 'Patient/1913132'}}
# {'category': [{'coding': [{'code': 'vital-signs',
#                            'system': 'http://hl7.org/fhir/observation-category'}]}],
#  'code': {'coding': [{'code': '39156-5',
#                       'display': 'Body Mass Index',
#                       'system': 'http://loinc.org'}],
#           'text': 'Body Mass Index'},
#  'context': {'reference': 'Encounter/1913141'},
#  'effectiveDateTime': '2009-10-04T10:00:59-04:00',
#  'id': '1913145',
#  'issued': '2009-10-04T10:00:59-04:00',
#  'meta': {'lastUpdated': '2019-05-09T10:09:50.460+00:00',
#           'profile': ['http://standardhealthrecord.org/fhir/StructureDefinition/shr-observation-Observation',
#                       'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-VitalSign',
#                       'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-BodyMassIndex'],
#           'versionId': '1'},
#  'resourceType': 'Observation',
#  'status': 'final',
#  'subject': {'reference': 'Patient/1913132'},
#  'valueQuantity': {'code': 'kg/m2',
#                    'system': 'http://unitsofmeasure.org',
#                    'unit': 'kg/m2',
#                    'value': 40.74551734672138}}
# {'category': [{'coding': [{'code': 'vital-signs',
#                            'system': 'http://hl7.org/fhir/observation-category'}]}],
#  'code': {'coding': [{'code': '29463-7',
#                       'display': 'Body Weight',
#                       'system': 'http://loinc.org'}],
#           'text': 'Body Weight'},
#  'context': {'reference': 'Encounter/1913141'},
#  'effectiveDateTime': '2009-10-04T10:00:59-04:00',
#  'id': '1913144',
#  'issued': '2009-10-04T10:00:59-04:00',
#  'meta': {'lastUpdated': '2019-05-09T10:09:50.460+00:00',
#           'profile': ['http://standardhealthrecord.org/fhir/StructureDefinition/shr-observation-Observation',
#                       'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-VitalSign',
#                       'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-BodyWeight'],
#           'versionId': '1'},
#  'resourceType': 'Observation',
#  'status': 'final',
#  'subject': {'reference': 'Patient/1913132'},
#  'valueQuantity': {'code': 'kg',
#                    'system': 'http://unitsofmeasure.org',
#                    'unit': 'kg',
#                    'value': 121.21689457373371}}
# {'category': [{'coding': [{'code': 'vital-signs',
#                            'system': 'http://hl7.org/fhir/observation-category'}]}],
#  'code': {'coding': [{'code': '8302-2',
#                       'display': 'Body Height',
#                       'system': 'http://loinc.org'}],
#           'text': 'Body Height'},
#  'context': {'reference': 'Encounter/1913141'},
#  'effectiveDateTime': '2009-10-04T10:00:59-04:00',
#  'id': '1913143',
#  'issued': '2009-10-04T10:00:59-04:00',
#  'meta': {'lastUpdated': '2019-05-09T10:09:50.460+00:00',
#           'profile': ['http://standardhealthrecord.org/fhir/StructureDefinition/shr-observation-Observation',
#                       'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-VitalSign',
#                       'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-BodyHeight'],
#           'versionId': '1'},
#  'resourceType': 'Observation',
#  'status': 'final',
#  'subject': {'reference': 'Patient/1913132'},
#  'valueQuantity': {'code': 'cm',
#                    'system': 'http://unitsofmeasure.org',
#                    'unit': 'cm',
#                    'value': 172.4811577546544}}
# {'category': [{'coding': [{'code': 'vital-signs',
#                            'system': 'http://hl7.org/fhir/observation-category'}]}],
#  'code': {'coding': [{'code': '29463-7',
#                       'display': 'Body Weight',
#                       'system': 'http://loinc.org'}],
#           'text': 'Body Weight'},
#  'context': {'reference': 'Encounter/1913156'},
#  'effectiveDateTime': '2011-09-12T13:29:49-04:00',
#  'id': '1913159',
#  'issued': '2011-09-12T13:29:49-04:00',
#  'meta': {'lastUpdated': '2019-05-09T10:09:50.460+00:00',
#           'profile': ['http://standardhealthrecord.org/fhir/StructureDefinition/shr-observation-Observation',
#                       'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-VitalSign',
#                       'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-BodyWeight'],
#           'versionId': '1'},
#  'resourceType': 'Observation',
#  'status': 'final',
#  'subject': {'reference': 'Patient/1913132'},
#  'valueQuantity': {'code': 'kg',
#                    'system': 'http://unitsofmeasure.org',
#                    'unit': 'kg',
#                    'value': 121.21689457373371}}
# {'category': [{'coding': [{'code': 'vital-signs',
#                            'system': 'http://hl7.org/fhir/observation-category'}]}],
#  'code': {'coding': [{'code': '8302-2',
#                       'display': 'Body Height',
#                       'system': 'http://loinc.org'}],
#           'text': 'Body Height'},
#  'context': {'reference': 'Encounter/1913156'},
#  'effectiveDateTime': '2011-09-12T13:29:49-04:00',
#  'id': '1913158',
#  'issued': '2011-09-12T13:29:49-04:00',
#  'meta': {'lastUpdated': '2019-05-09T10:09:50.460+00:00',
#           'profile': ['http://standardhealthrecord.org/fhir/StructureDefinition/shr-observation-Observation',
#                       'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-VitalSign',
#                       'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-BodyHeight'],
#           'versionId': '1'},
#  'resourceType': 'Observation',
#  'status': 'final',
#  'subject': {'reference': 'Patient/1913132'},
#  'valueQuantity': {'code': 'cm',
#                    'system': 'http://unitsofmeasure.org',
#                    'unit': 'cm',
#                    'value': 172.4811577546544}}
# {'category': [{'coding': [{'code': 'vital-signs',
#                            'system': 'http://hl7.org/fhir/observation-category'}]}],
#  'code': {'coding': [{'code': '55284-4',
#                       'display': 'Blood Pressure',
#                       'system': 'http://loinc.org'}]},
#  'component': [{'code': {'coding': [{'code': '8480-6',
#                                      'display': 'Systolic Blood Pressure',
#                                      'system': 'http://loinc.org'}],
#                          'text': 'Systolic Blood Pressure'},
#                 'valueQuantity': {'code': 'mmHg',
#                                   'system': 'http://unitsofmeasure.org',
#                                   'unit': 'mmHg',
#                                   'value': 118}},
#                {'code': {'coding': [{'code': '8462-4',
#                                      'display': 'Diastolic Blood Pressure',
#                                      'system': 'http://loinc.org'}],
#                          'text': 'Diastolic Blood Pressure'},
#                 'valueQuantity': {'code': 'mmHg',
#                                   'system': 'http://unitsofmeasure.org',
#                                   'unit': 'mmHg',
#                                   'value': 70}}],
#  'context': {'reference': 'Encounter/1913148'},
#  'effectiveDateTime': '2010-07-22T02:24:44-04:00',
#  'id': '1913153',
#  'issued': '2010-07-22T02:24:44-04:00',
#  'meta': {'lastUpdated': '2019-05-09T10:09:50.460+00:00',
#           'profile': ['http://standardhealthrecord.org/fhir/StructureDefinition/shr-observation-Observation',
#                       'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-BloodPressure'],
#           'versionId': '1'},
#  'resourceType': 'Observation',
#  'status': 'final',
#  'subject': {'reference': 'Patient/1913132'}}
# {'category': [{'coding': [{'code': 'vital-signs',
#                            'system': 'http://hl7.org/fhir/observation-category'}]}],
#  'code': {'coding': [{'code': '39156-5',
#                       'display': 'Body Mass Index',
#                       'system': 'http://loinc.org'}],
#           'text': 'Body Mass Index'},
#  'context': {'reference': 'Encounter/1913148'},
#  'effectiveDateTime': '2010-07-22T02:24:44-04:00',
#  'id': '1913152',
#  'issued': '2010-07-22T02:24:44-04:00',
#  'meta': {'lastUpdated': '2019-05-09T10:09:50.460+00:00',
#           'profile': ['http://standardhealthrecord.org/fhir/StructureDefinition/shr-observation-Observation',
#                       'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-VitalSign',
#                       'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-BodyMassIndex'],
#           'versionId': '1'},
#  'resourceType': 'Observation',
#  'status': 'final',
#  'subject': {'reference': 'Patient/1913132'},
#  'valueQuantity': {'code': 'kg/m2',
#                    'system': 'http://unitsofmeasure.org',
#                    'unit': 'kg/m2',
#                    'value': 40.74551734672138}}
# {'category': [{'coding': [{'code': 'vital-signs',
#                            'system': 'http://hl7.org/fhir/observation-category'}]}],
#  'code': {'coding': [{'code': '29463-7',
#                       'display': 'Body Weight',
#                       'system': 'http://loinc.org'}],
#           'text': 'Body Weight'},
#  'context': {'reference': 'Encounter/1913148'},
#  'effectiveDateTime': '2010-07-22T02:24:44-04:00',
#  'id': '1913151',
#  'issued': '2010-07-22T02:24:44-04:00',
#  'meta': {'lastUpdated': '2019-05-09T10:09:50.460+00:00',
#           'profile': ['http://standardhealthrecord.org/fhir/StructureDefinition/shr-observation-Observation',
#                       'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-VitalSign',
#                       'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-BodyWeight'],
#           'versionId': '1'},
#  'resourceType': 'Observation',
#  'status': 'final',
#  'subject': {'reference': 'Patient/1913132'},
#  'valueQuantity': {'code': 'kg',
#                    'system': 'http://unitsofmeasure.org',
#                    'unit': 'kg',
#                    'value': 121.21689457373371}}
# {'category': [{'coding': [{'code': 'vital-signs',
#                            'system': 'http://hl7.org/fhir/observation-category'}]}],
#  'code': {'coding': [{'code': '8302-2',
#                       'display': 'Body Height',
#                       'system': 'http://loinc.org'}],
#           'text': 'Body Height'},
#  'context': {'reference': 'Encounter/1913148'},
#  'effectiveDateTime': '2010-07-22T02:24:44-04:00',
#  'id': '1913150',
#  'issued': '2010-07-22T02:24:44-04:00',
#  'meta': {'lastUpdated': '2019-05-09T10:09:50.460+00:00',
#           'profile': ['http://standardhealthrecord.org/fhir/StructureDefinition/shr-observation-Observation',
#                       'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-VitalSign',
#                       'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-BodyHeight'],
#           'versionId': '1'},
#  'resourceType': 'Observation',
#  'status': 'final',
#  'subject': {'reference': 'Patient/1913132'},
#  'valueQuantity': {'code': 'cm',
#                    'system': 'http://unitsofmeasure.org',
#                    'unit': 'cm',
#                    'value': 172.4811577546544}}
# {'category': [{'coding': [{'code': 'vital-signs',
#                            'system': 'http://hl7.org/fhir/observation-category'}]}],
#  'code': {'coding': [{'code': '8331-1',
#                       'display': 'Oral temperature',
#                       'system': 'http://loinc.org'}],
#           'text': 'Oral temperature'},
#  'context': {'reference': 'Encounter/1913199'},
#  'effectiveDateTime': '2015-02-20T19:42:38-04:00',
#  'id': '1913202',
#  'issued': '2015-02-20T19:42:38-04:00',
#  'meta': {'lastUpdated': '2019-05-09T10:09:50.460+00:00',
#           'profile': ['http://standardhealthrecord.org/fhir/StructureDefinition/shr-observation-Observation',
#                       'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-VitalSign'],
#           'versionId': '1'},
#  'resourceType': 'Observation',
#  'status': 'final',
#  'subject': {'reference': 'Patient/1913132'},
#  'valueQuantity': {'code': 'Cel',
#                    'system': 'http://unitsofmeasure.org',
#                    'unit': 'Cel',
#                    'value': 37}}
# {'category': [{'coding': [{'code': 'laboratory',
#                            'system': 'http://hl7.org/fhir/observation-category'}]}],
#  'code': {'coding': [{'code': '2085-9',
#                       'display': 'High Density Lipoprotein Cholesterol',
#                       'system': 'http://loinc.org'}],
#           'text': 'High Density Lipoprotein Cholesterol'},
#  'context': {'reference': 'Encounter/1913156'},
#  'effectiveDateTime': '2011-09-12T13:29:49-04:00',
#  'id': '1913165',
#  'issued': '2011-09-12T13:29:49-04:00',
#  'meta': {'lastUpdated': '2019-05-09T10:09:50.460+00:00',
#           'profile': ['http://standardhealthrecord.org/fhir/StructureDefinition/shr-observation-Observation'],
#           'versionId': '1'},
#  'resourceType': 'Observation',
#  'status': 'final',
#  'subject': {'reference': 'Patient/1913132'},
#  'valueQuantity': {'code': 'mg/dL',
#                    'system': 'http://unitsofmeasure.org',
#                    'unit': 'mg/dL',
#                    'value': 60}}
# {'category': [{'coding': [{'code': 'laboratory',
#                            'system': 'http://hl7.org/fhir/observation-category'}]}],
#  'code': {'coding': [{'code': '18262-6',
#                       'display': 'Low Density Lipoprotein Cholesterol',
#                       'system': 'http://loinc.org'}],
#           'text': 'Low Density Lipoprotein Cholesterol'},
#  'context': {'reference': 'Encounter/1913156'},
#  'effectiveDateTime': '2011-09-12T13:29:49-04:00',
#  'id': '1913164',
#  'issued': '2011-09-12T13:29:49-04:00',
#  'meta': {'lastUpdated': '2019-05-09T10:09:50.460+00:00',
#           'profile': ['http://standardhealthrecord.org/fhir/StructureDefinition/shr-observation-Observation'],
#           'versionId': '1'},
#  'resourceType': 'Observation',
#  'status': 'final',
#  'subject': {'reference': 'Patient/1913132'},
#  'valueQuantity': {'code': 'mg/dL',
#                    'system': 'http://unitsofmeasure.org',
#                    'unit': 'mg/dL',
#                    'value': 116}}
# {'category': [{'coding': [{'code': 'laboratory',
#                            'system': 'http://hl7.org/fhir/observation-category'}]}],
#  'code': {'coding': [{'code': '2571-8',
#                       'display': 'Triglycerides',
#                       'system': 'http://loinc.org'}],
#           'text': 'Triglycerides'},
#  'context': {'reference': 'Encounter/1913156'},
#  'effectiveDateTime': '2011-09-12T13:29:49-04:00',
#  'id': '1913163',
#  'issued': '2011-09-12T13:29:49-04:00',
#  'meta': {'lastUpdated': '2019-05-09T10:09:50.460+00:00',
#           'profile': ['http://standardhealthrecord.org/fhir/StructureDefinition/shr-observation-Observation'],
#           'versionId': '1'},
#  'resourceType': 'Observation',
#  'status': 'final',
#  'subject': {'reference': 'Patient/1913132'},
#  'valueQuantity': {'code': 'mg/dL',
#                    'system': 'http://unitsofmeasure.org',
#                    'unit': 'mg/dL',
#                    'value': 109}}
# {'category': [{'coding': [{'code': 'laboratory',
#                            'system': 'http://hl7.org/fhir/observation-category'}]}],
#  'code': {'coding': [{'code': '2093-3',
#                       'display': 'Total Cholesterol',
#                       'system': 'http://loinc.org'}],
#           'text': 'Total Cholesterol'},
#  'context': {'reference': 'Encounter/1913156'},
#  'effectiveDateTime': '2011-09-12T13:29:49-04:00',
#  'id': '1913162',
#  'issued': '2011-09-12T13:29:49-04:00',
#  'meta': {'lastUpdated': '2019-05-09T10:09:50.460+00:00',
#           'profile': ['http://standardhealthrecord.org/fhir/StructureDefinition/shr-observation-Observation'],
#           'versionId': '1'},
#  'resourceType': 'Observation',
#  'status': 'final',
#  'subject': {'reference': 'Patient/1913132'},
#  'valueQuantity': {'code': 'mg/dL',
#                    'system': 'http://unitsofmeasure.org',
#                    'unit': 'mg/dL',
#                    'value': 198}}
# {'category': [{'coding': [{'code': 'vital-signs',
#                            'system': 'http://hl7.org/fhir/observation-category'}]}],
#  'code': {'coding': [{'code': '55284-4',
#                       'display': 'Blood Pressure',
#                       'system': 'http://loinc.org'}]},
#  'component': [{'code': {'coding': [{'code': '8480-6',
#                                      'display': 'Systolic Blood Pressure',
#                                      'system': 'http://loinc.org'}],
#                          'text': 'Systolic Blood Pressure'},
#                 'valueQuantity': {'code': 'mmHg',
#                                   'system': 'http://unitsofmeasure.org',
#                                   'unit': 'mmHg',
#                                   'value': 106}},
#                {'code': {'coding': [{'code': '8462-4',
#                                      'display': 'Diastolic Blood Pressure',
#                                      'system': 'http://loinc.org'}],
#                          'text': 'Diastolic Blood Pressure'},
#                 'valueQuantity': {'code': 'mmHg',
#                                   'system': 'http://unitsofmeasure.org',
#                                   'unit': 'mmHg',
#                                   'value': 80}}],
#  'context': {'reference': 'Encounter/1913156'},
#  'effectiveDateTime': '2011-09-12T13:29:49-04:00',
#  'id': '1913161',
#  'issued': '2011-09-12T13:29:49-04:00',
#  'meta': {'lastUpdated': '2019-05-09T10:09:50.460+00:00',
#           'profile': ['http://standardhealthrecord.org/fhir/StructureDefinition/shr-observation-Observation',
#                       'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-BloodPressure'],
#           'versionId': '1'},
#  'resourceType': 'Observation',
#  'status': 'final',
#  'subject': {'reference': 'Patient/1913132'}}

# %%
# to get the raw Bundle instead of resources only, you can use:
bundle = search.perform(smart.server)
pprint(bundle.as_json())
# Out:
# {'entry': [{'fullUrl': 'http://hapi.fhir.org/baseDstu3/Observation/1913246',
#             'resource': {'category': [{'coding': [{'code': 'vital-signs',
#                                                    'system': 'http://hl7.org/fhir/observation-category'}]}],
#                          'code': {'coding': [{'code': '55284-4',
#                                               'display': 'Blood Pressure',
#                                               'system': 'http://loinc.org'}]},
#                          'component': [{'code': {'coding': [{'code': '8480-6',
#                                                              'display': 'Systolic '
#                                                                         'Blood '
#                                                                         'Pressure',
#                                                              'system': 'http://loinc.org'}],
#                                                  'text': 'Systolic Blood '
#                                                          'Pressure'},
#                                         'valueQuantity': {'code': 'mmHg',
#                                                           'system': 'http://unitsofmeasure.org',
#                                                           'unit': 'mmHg',
#                                                           'value': 131}},
#                                        {'code': {'coding': [{'code': '8462-4',
#                                                              'display': 'Diastolic '
#                                                                         'Blood '
#                                                                         'Pressure',
#                                                              'system': 'http://loinc.org'}],
#                                                  'text': 'Diastolic Blood '
#                                                          'Pressure'},
#                                         'valueQuantity': {'code': 'mmHg',
#                                                           'system': 'http://unitsofmeasure.org',
#                                                           'unit': 'mmHg',
#                                                           'value': 77}}],
#                          'context': {'reference': 'Encounter/1913241'},
#                          'effectiveDateTime': '2019-02-10T01:13:13-04:00',
#                          'id': '1913246',
#                          'issued': '2019-02-10T01:13:13-04:00',
#                          'meta': {'lastUpdated': '2019-05-09T10:09:50.460+00:00',
#                                   'profile': ['http://standardhealthrecord.org/fhir/StructureDefinition/shr-observation-Observation',
#                                               'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-BloodPressure'],
#                                   'versionId': '1'},
#                          'resourceType': 'Observation',
#                          'status': 'final',
#                          'subject': {'reference': 'Patient/1913132'}},
#             'search': {'mode': 'match'}},
#            {'fullUrl': 'http://hapi.fhir.org/baseDstu3/Observation/1913245',
#             'resource': {'category': [{'coding': [{'code': 'vital-signs',
#                                                    'system': 'http://hl7.org/fhir/observation-category'}]}],
#                          'code': {'coding': [{'code': '39156-5',
#                                               'display': 'Body Mass Index',
#                                               'system': 'http://loinc.org'}],
#                                   'text': 'Body Mass Index'},
#                          'context': {'reference': 'Encounter/1913241'},
#                          'effectiveDateTime': '2019-02-10T01:13:13-04:00',
#                          'id': '1913245',
#                          'issued': '2019-02-10T01:13:13-04:00',
#                          'meta': {'lastUpdated': '2019-05-09T10:09:50.460+00:00',
#                                   'profile': ['http://standardhealthrecord.org/fhir/StructureDefinition/shr-observation-Observation',
#                                               'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-VitalSign',
#                                               'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-BodyMassIndex'],
#                                   'versionId': '1'},
#                          'resourceType': 'Observation',
#                          'status': 'final',
#                          'subject': {'reference': 'Patient/1913132'},
#                          'valueQuantity': {'code': 'kg/m2',
#                                            'system': 'http://unitsofmeasure.org',
#                                            'unit': 'kg/m2',
#                                            'value': 38.35790913354118}},
#             'search': {'mode': 'match'}},
#            {'fullUrl': 'http://hapi.fhir.org/baseDstu3/Observation/1913244',
#             'resource': {'category': [{'coding': [{'code': 'vital-signs',
#                                                    'system': 'http://hl7.org/fhir/observation-category'}]}],
#                          'code': {'coding': [{'code': '29463-7',
#                                               'display': 'Body Weight',
#                                               'system': 'http://loinc.org'}],
#                                   'text': 'Body Weight'},
#                          'context': {'reference': 'Encounter/1913241'},
#                          'effectiveDateTime': '2019-02-10T01:13:13-04:00',
#                          'id': '1913244',
#                          'issued': '2019-02-10T01:13:13-04:00',
#                          'meta': {'lastUpdated': '2019-05-09T10:09:50.460+00:00',
#                                   'profile': ['http://standardhealthrecord.org/fhir/StructureDefinition/shr-observation-Observation',
#                                               'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-VitalSign',
#                                               'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-BodyWeight'],
#                                   'versionId': '1'},
#                          'resourceType': 'Observation',
#                          'status': 'final',
#                          'subject': {'reference': 'Patient/1913132'},
#                          'valueQuantity': {'code': 'kg',
#                                            'system': 'http://unitsofmeasure.org',
#                                            'unit': 'kg',
#                                            'value': 114.11381988216317}},
#             'search': {'mode': 'match'}},
#            {'fullUrl': 'http://hapi.fhir.org/baseDstu3/Observation/1913243',
#             'resource': {'category': [{'coding': [{'code': 'vital-signs',
#                                                    'system': 'http://hl7.org/fhir/observation-category'}]}],
#                          'code': {'coding': [{'code': '8302-2',
#                                               'display': 'Body Height',
#                                               'system': 'http://loinc.org'}],
#                                   'text': 'Body Height'},
#                          'context': {'reference': 'Encounter/1913241'},
#                          'effectiveDateTime': '2019-02-10T01:13:13-04:00',
#                          'id': '1913243',
#                          'issued': '2019-02-10T01:13:13-04:00',
#                          'meta': {'lastUpdated': '2019-05-09T10:09:50.460+00:00',
#                                   'profile': ['http://standardhealthrecord.org/fhir/StructureDefinition/shr-observation-Observation',
#                                               'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-VitalSign',
#                                               'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-BodyHeight'],
#                                   'versionId': '1'},
#                          'resourceType': 'Observation',
#                          'status': 'final',
#                          'subject': {'reference': 'Patient/1913132'},
#                          'valueQuantity': {'code': 'cm',
#                                            'system': 'http://unitsofmeasure.org',
#                                            'unit': 'cm',
#                                            'value': 172.4811577546544}},
#             'search': {'mode': 'match'}},
#            {'fullUrl': 'http://hapi.fhir.org/baseDstu3/Observation/1913146',
#             'resource': {'category': [{'coding': [{'code': 'vital-signs',
#                                                    'system': 'http://hl7.org/fhir/observation-category'}]}],
#                          'code': {'coding': [{'code': '55284-4',
#                                               'display': 'Blood Pressure',
#                                               'system': 'http://loinc.org'}]},
#                          'component': [{'code': {'coding': [{'code': '8480-6',
#                                                              'display': 'Systolic '
#                                                                         'Blood '
#                                                                         'Pressure',
#                                                              'system': 'http://loinc.org'}],
#                                                  'text': 'Systolic Blood '
#                                                          'Pressure'},
#                                         'valueQuantity': {'code': 'mmHg',
#                                                           'system': 'http://unitsofmeasure.org',
#                                                           'unit': 'mmHg',
#                                                           'value': 122}},
#                                        {'code': {'coding': [{'code': '8462-4',
#                                                              'display': 'Diastolic '
#                                                                         'Blood '
#                                                                         'Pressure',
#                                                              'system': 'http://loinc.org'}],
#                                                  'text': 'Diastolic Blood '
#                                                          'Pressure'},
#                                         'valueQuantity': {'code': 'mmHg',
#                                                           'system': 'http://unitsofmeasure.org',
#                                                           'unit': 'mmHg',
#                                                           'value': 89}}],
#                          'context': {'reference': 'Encounter/1913141'},
#                          'effectiveDateTime': '2009-10-04T10:00:59-04:00',
#                          'id': '1913146',
#                          'issued': '2009-10-04T10:00:59-04:00',
#                          'meta': {'lastUpdated': '2019-05-09T10:09:50.460+00:00',
#                                   'profile': ['http://standardhealthrecord.org/fhir/StructureDefinition/shr-observation-Observation',
#                                               'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-BloodPressure'],
#                                   'versionId': '1'},
#                          'resourceType': 'Observation',
#                          'status': 'final',
#                          'subject': {'reference': 'Patient/1913132'}},
#             'search': {'mode': 'match'}},
#            {'fullUrl': 'http://hapi.fhir.org/baseDstu3/Observation/1913145',
#             'resource': {'category': [{'coding': [{'code': 'vital-signs',
#                                                    'system': 'http://hl7.org/fhir/observation-category'}]}],
#                          'code': {'coding': [{'code': '39156-5',
#                                               'display': 'Body Mass Index',
#                                               'system': 'http://loinc.org'}],
#                                   'text': 'Body Mass Index'},
#                          'context': {'reference': 'Encounter/1913141'},
#                          'effectiveDateTime': '2009-10-04T10:00:59-04:00',
#                          'id': '1913145',
#                          'issued': '2009-10-04T10:00:59-04:00',
#                          'meta': {'lastUpdated': '2019-05-09T10:09:50.460+00:00',
#                                   'profile': ['http://standardhealthrecord.org/fhir/StructureDefinition/shr-observation-Observation',
#                                               'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-VitalSign',
#                                               'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-BodyMassIndex'],
#                                   'versionId': '1'},
#                          'resourceType': 'Observation',
#                          'status': 'final',
#                          'subject': {'reference': 'Patient/1913132'},
#                          'valueQuantity': {'code': 'kg/m2',
#                                            'system': 'http://unitsofmeasure.org',
#                                            'unit': 'kg/m2',
#                                            'value': 40.74551734672138}},
#             'search': {'mode': 'match'}},
#            {'fullUrl': 'http://hapi.fhir.org/baseDstu3/Observation/1913144',
#             'resource': {'category': [{'coding': [{'code': 'vital-signs',
#                                                    'system': 'http://hl7.org/fhir/observation-category'}]}],
#                          'code': {'coding': [{'code': '29463-7',
#                                               'display': 'Body Weight',
#                                               'system': 'http://loinc.org'}],
#                                   'text': 'Body Weight'},
#                          'context': {'reference': 'Encounter/1913141'},
#                          'effectiveDateTime': '2009-10-04T10:00:59-04:00',
#                          'id': '1913144',
#                          'issued': '2009-10-04T10:00:59-04:00',
#                          'meta': {'lastUpdated': '2019-05-09T10:09:50.460+00:00',
#                                   'profile': ['http://standardhealthrecord.org/fhir/StructureDefinition/shr-observation-Observation',
#                                               'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-VitalSign',
#                                               'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-BodyWeight'],
#                                   'versionId': '1'},
#                          'resourceType': 'Observation',
#                          'status': 'final',
#                          'subject': {'reference': 'Patient/1913132'},
#                          'valueQuantity': {'code': 'kg',
#                                            'system': 'http://unitsofmeasure.org',
#                                            'unit': 'kg',
#                                            'value': 121.21689457373371}},
#             'search': {'mode': 'match'}},
#            {'fullUrl': 'http://hapi.fhir.org/baseDstu3/Observation/1913143',
#             'resource': {'category': [{'coding': [{'code': 'vital-signs',
#                                                    'system': 'http://hl7.org/fhir/observation-category'}]}],
#                          'code': {'coding': [{'code': '8302-2',
#                                               'display': 'Body Height',
#                                               'system': 'http://loinc.org'}],
#                                   'text': 'Body Height'},
#                          'context': {'reference': 'Encounter/1913141'},
#                          'effectiveDateTime': '2009-10-04T10:00:59-04:00',
#                          'id': '1913143',
#                          'issued': '2009-10-04T10:00:59-04:00',
#                          'meta': {'lastUpdated': '2019-05-09T10:09:50.460+00:00',
#                                   'profile': ['http://standardhealthrecord.org/fhir/StructureDefinition/shr-observation-Observation',
#                                               'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-VitalSign',
#                                               'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-BodyHeight'],
#                                   'versionId': '1'},
#                          'resourceType': 'Observation',
#                          'status': 'final',
#                          'subject': {'reference': 'Patient/1913132'},
#                          'valueQuantity': {'code': 'cm',
#                                            'system': 'http://unitsofmeasure.org',
#                                            'unit': 'cm',
#                                            'value': 172.4811577546544}},
#             'search': {'mode': 'match'}},
#            {'fullUrl': 'http://hapi.fhir.org/baseDstu3/Observation/1913159',
#             'resource': {'category': [{'coding': [{'code': 'vital-signs',
#                                                    'system': 'http://hl7.org/fhir/observation-category'}]}],
#                          'code': {'coding': [{'code': '29463-7',
#                                               'display': 'Body Weight',
#                                               'system': 'http://loinc.org'}],
#                                   'text': 'Body Weight'},
#                          'context': {'reference': 'Encounter/1913156'},
#                          'effectiveDateTime': '2011-09-12T13:29:49-04:00',
#                          'id': '1913159',
#                          'issued': '2011-09-12T13:29:49-04:00',
#                          'meta': {'lastUpdated': '2019-05-09T10:09:50.460+00:00',
#                                   'profile': ['http://standardhealthrecord.org/fhir/StructureDefinition/shr-observation-Observation',
#                                               'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-VitalSign',
#                                               'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-BodyWeight'],
#                                   'versionId': '1'},
#                          'resourceType': 'Observation',
#                          'status': 'final',
#                          'subject': {'reference': 'Patient/1913132'},
#                          'valueQuantity': {'code': 'kg',
#                                            'system': 'http://unitsofmeasure.org',
#                                            'unit': 'kg',
#                                            'value': 121.21689457373371}},
#             'search': {'mode': 'match'}},
#            {'fullUrl': 'http://hapi.fhir.org/baseDstu3/Observation/1913158',
#             'resource': {'category': [{'coding': [{'code': 'vital-signs',
#                                                    'system': 'http://hl7.org/fhir/observation-category'}]}],
#                          'code': {'coding': [{'code': '8302-2',
#                                               'display': 'Body Height',
#                                               'system': 'http://loinc.org'}],
#                                   'text': 'Body Height'},
#                          'context': {'reference': 'Encounter/1913156'},
#                          'effectiveDateTime': '2011-09-12T13:29:49-04:00',
#                          'id': '1913158',
#                          'issued': '2011-09-12T13:29:49-04:00',
#                          'meta': {'lastUpdated': '2019-05-09T10:09:50.460+00:00',
#                                   'profile': ['http://standardhealthrecord.org/fhir/StructureDefinition/shr-observation-Observation',
#                                               'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-VitalSign',
#                                               'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-BodyHeight'],
#                                   'versionId': '1'},
#                          'resourceType': 'Observation',
#                          'status': 'final',
#                          'subject': {'reference': 'Patient/1913132'},
#                          'valueQuantity': {'code': 'cm',
#                                            'system': 'http://unitsofmeasure.org',
#                                            'unit': 'cm',
#                                            'value': 172.4811577546544}},
#             'search': {'mode': 'match'}},
#            {'fullUrl': 'http://hapi.fhir.org/baseDstu3/Observation/1913153',
#             'resource': {'category': [{'coding': [{'code': 'vital-signs',
#                                                    'system': 'http://hl7.org/fhir/observation-category'}]}],
#                          'code': {'coding': [{'code': '55284-4',
#                                               'display': 'Blood Pressure',
#                                               'system': 'http://loinc.org'}]},
#                          'component': [{'code': {'coding': [{'code': '8480-6',
#                                                              'display': 'Systolic '
#                                                                         'Blood '
#                                                                         'Pressure',
#                                                              'system': 'http://loinc.org'}],
#                                                  'text': 'Systolic Blood '
#                                                          'Pressure'},
#                                         'valueQuantity': {'code': 'mmHg',
#                                                           'system': 'http://unitsofmeasure.org',
#                                                           'unit': 'mmHg',
#                                                           'value': 118}},
#                                        {'code': {'coding': [{'code': '8462-4',
#                                                              'display': 'Diastolic '
#                                                                         'Blood '
#                                                                         'Pressure',
#                                                              'system': 'http://loinc.org'}],
#                                                  'text': 'Diastolic Blood '
#                                                          'Pressure'},
#                                         'valueQuantity': {'code': 'mmHg',
#                                                           'system': 'http://unitsofmeasure.org',
#                                                           'unit': 'mmHg',
#                                                           'value': 70}}],
#                          'context': {'reference': 'Encounter/1913148'},
#                          'effectiveDateTime': '2010-07-22T02:24:44-04:00',
#                          'id': '1913153',
#                          'issued': '2010-07-22T02:24:44-04:00',
#                          'meta': {'lastUpdated': '2019-05-09T10:09:50.460+00:00',
#                                   'profile': ['http://standardhealthrecord.org/fhir/StructureDefinition/shr-observation-Observation',
#                                               'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-BloodPressure'],
#                                   'versionId': '1'},
#                          'resourceType': 'Observation',
#                          'status': 'final',
#                          'subject': {'reference': 'Patient/1913132'}},
#             'search': {'mode': 'match'}},
#            {'fullUrl': 'http://hapi.fhir.org/baseDstu3/Observation/1913152',
#             'resource': {'category': [{'coding': [{'code': 'vital-signs',
#                                                    'system': 'http://hl7.org/fhir/observation-category'}]}],
#                          'code': {'coding': [{'code': '39156-5',
#                                               'display': 'Body Mass Index',
#                                               'system': 'http://loinc.org'}],
#                                   'text': 'Body Mass Index'},
#                          'context': {'reference': 'Encounter/1913148'},
#                          'effectiveDateTime': '2010-07-22T02:24:44-04:00',
#                          'id': '1913152',
#                          'issued': '2010-07-22T02:24:44-04:00',
#                          'meta': {'lastUpdated': '2019-05-09T10:09:50.460+00:00',
#                                   'profile': ['http://standardhealthrecord.org/fhir/StructureDefinition/shr-observation-Observation',
#                                               'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-VitalSign',
#                                               'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-BodyMassIndex'],
#                                   'versionId': '1'},
#                          'resourceType': 'Observation',
#                          'status': 'final',
#                          'subject': {'reference': 'Patient/1913132'},
#                          'valueQuantity': {'code': 'kg/m2',
#                                            'system': 'http://unitsofmeasure.org',
#                                            'unit': 'kg/m2',
#                                            'value': 40.74551734672138}},
#             'search': {'mode': 'match'}},
#            {'fullUrl': 'http://hapi.fhir.org/baseDstu3/Observation/1913151',
#             'resource': {'category': [{'coding': [{'code': 'vital-signs',
#                                                    'system': 'http://hl7.org/fhir/observation-category'}]}],
#                          'code': {'coding': [{'code': '29463-7',
#                                               'display': 'Body Weight',
#                                               'system': 'http://loinc.org'}],
#                                   'text': 'Body Weight'},
#                          'context': {'reference': 'Encounter/1913148'},
#                          'effectiveDateTime': '2010-07-22T02:24:44-04:00',
#                          'id': '1913151',
#                          'issued': '2010-07-22T02:24:44-04:00',
#                          'meta': {'lastUpdated': '2019-05-09T10:09:50.460+00:00',
#                                   'profile': ['http://standardhealthrecord.org/fhir/StructureDefinition/shr-observation-Observation',
#                                               'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-VitalSign',
#                                               'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-BodyWeight'],
#                                   'versionId': '1'},
#                          'resourceType': 'Observation',
#                          'status': 'final',
#                          'subject': {'reference': 'Patient/1913132'},
#                          'valueQuantity': {'code': 'kg',
#                                            'system': 'http://unitsofmeasure.org',
#                                            'unit': 'kg',
#                                            'value': 121.21689457373371}},
#             'search': {'mode': 'match'}},
#            {'fullUrl': 'http://hapi.fhir.org/baseDstu3/Observation/1913150',
#             'resource': {'category': [{'coding': [{'code': 'vital-signs',
#                                                    'system': 'http://hl7.org/fhir/observation-category'}]}],
#                          'code': {'coding': [{'code': '8302-2',
#                                               'display': 'Body Height',
#                                               'system': 'http://loinc.org'}],
#                                   'text': 'Body Height'},
#                          'context': {'reference': 'Encounter/1913148'},
#                          'effectiveDateTime': '2010-07-22T02:24:44-04:00',
#                          'id': '1913150',
#                          'issued': '2010-07-22T02:24:44-04:00',
#                          'meta': {'lastUpdated': '2019-05-09T10:09:50.460+00:00',
#                                   'profile': ['http://standardhealthrecord.org/fhir/StructureDefinition/shr-observation-Observation',
#                                               'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-VitalSign',
#                                               'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-BodyHeight'],
#                                   'versionId': '1'},
#                          'resourceType': 'Observation',
#                          'status': 'final',
#                          'subject': {'reference': 'Patient/1913132'},
#                          'valueQuantity': {'code': 'cm',
#                                            'system': 'http://unitsofmeasure.org',
#                                            'unit': 'cm',
#                                            'value': 172.4811577546544}},
#             'search': {'mode': 'match'}},
#            {'fullUrl': 'http://hapi.fhir.org/baseDstu3/Observation/1913202',
#             'resource': {'category': [{'coding': [{'code': 'vital-signs',
#                                                    'system': 'http://hl7.org/fhir/observation-category'}]}],
#                          'code': {'coding': [{'code': '8331-1',
#                                               'display': 'Oral temperature',
#                                               'system': 'http://loinc.org'}],
#                                   'text': 'Oral temperature'},
#                          'context': {'reference': 'Encounter/1913199'},
#                          'effectiveDateTime': '2015-02-20T19:42:38-04:00',
#                          'id': '1913202',
#                          'issued': '2015-02-20T19:42:38-04:00',
#                          'meta': {'lastUpdated': '2019-05-09T10:09:50.460+00:00',
#                                   'profile': ['http://standardhealthrecord.org/fhir/StructureDefinition/shr-observation-Observation',
#                                               'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-VitalSign'],
#                                   'versionId': '1'},
#                          'resourceType': 'Observation',
#                          'status': 'final',
#                          'subject': {'reference': 'Patient/1913132'},
#                          'valueQuantity': {'code': 'Cel',
#                                            'system': 'http://unitsofmeasure.org',
#                                            'unit': 'Cel',
#                                            'value': 37}},
#             'search': {'mode': 'match'}},
#            {'fullUrl': 'http://hapi.fhir.org/baseDstu3/Observation/1913165',
#             'resource': {'category': [{'coding': [{'code': 'laboratory',
#                                                    'system': 'http://hl7.org/fhir/observation-category'}]}],
#                          'code': {'coding': [{'code': '2085-9',
#                                               'display': 'High Density '
#                                                          'Lipoprotein '
#                                                          'Cholesterol',
#                                               'system': 'http://loinc.org'}],
#                                   'text': 'High Density Lipoprotein '
#                                           'Cholesterol'},
#                          'context': {'reference': 'Encounter/1913156'},
#                          'effectiveDateTime': '2011-09-12T13:29:49-04:00',
#                          'id': '1913165',
#                          'issued': '2011-09-12T13:29:49-04:00',
#                          'meta': {'lastUpdated': '2019-05-09T10:09:50.460+00:00',
#                                   'profile': ['http://standardhealthrecord.org/fhir/StructureDefinition/shr-observation-Observation'],
#                                   'versionId': '1'},
#                          'resourceType': 'Observation',
#                          'status': 'final',
#                          'subject': {'reference': 'Patient/1913132'},
#                          'valueQuantity': {'code': 'mg/dL',
#                                            'system': 'http://unitsofmeasure.org',
#                                            'unit': 'mg/dL',
#                                            'value': 60}},
#             'search': {'mode': 'match'}},
#            {'fullUrl': 'http://hapi.fhir.org/baseDstu3/Observation/1913164',
#             'resource': {'category': [{'coding': [{'code': 'laboratory',
#                                                    'system': 'http://hl7.org/fhir/observation-category'}]}],
#                          'code': {'coding': [{'code': '18262-6',
#                                               'display': 'Low Density '
#                                                          'Lipoprotein '
#                                                          'Cholesterol',
#                                               'system': 'http://loinc.org'}],
#                                   'text': 'Low Density Lipoprotein '
#                                           'Cholesterol'},
#                          'context': {'reference': 'Encounter/1913156'},
#                          'effectiveDateTime': '2011-09-12T13:29:49-04:00',
#                          'id': '1913164',
#                          'issued': '2011-09-12T13:29:49-04:00',
#                          'meta': {'lastUpdated': '2019-05-09T10:09:50.460+00:00',
#                                   'profile': ['http://standardhealthrecord.org/fhir/StructureDefinition/shr-observation-Observation'],
#                                   'versionId': '1'},
#                          'resourceType': 'Observation',
#                          'status': 'final',
#                          'subject': {'reference': 'Patient/1913132'},
#                          'valueQuantity': {'code': 'mg/dL',
#                                            'system': 'http://unitsofmeasure.org',
#                                            'unit': 'mg/dL',
#                                            'value': 116}},
#             'search': {'mode': 'match'}},
#            {'fullUrl': 'http://hapi.fhir.org/baseDstu3/Observation/1913163',
#             'resource': {'category': [{'coding': [{'code': 'laboratory',
#                                                    'system': 'http://hl7.org/fhir/observation-category'}]}],
#                          'code': {'coding': [{'code': '2571-8',
#                                               'display': 'Triglycerides',
#                                               'system': 'http://loinc.org'}],
#                                   'text': 'Triglycerides'},
#                          'context': {'reference': 'Encounter/1913156'},
#                          'effectiveDateTime': '2011-09-12T13:29:49-04:00',
#                          'id': '1913163',
#                          'issued': '2011-09-12T13:29:49-04:00',
#                          'meta': {'lastUpdated': '2019-05-09T10:09:50.460+00:00',
#                                   'profile': ['http://standardhealthrecord.org/fhir/StructureDefinition/shr-observation-Observation'],
#                                   'versionId': '1'},
#                          'resourceType': 'Observation',
#                          'status': 'final',
#                          'subject': {'reference': 'Patient/1913132'},
#                          'valueQuantity': {'code': 'mg/dL',
#                                            'system': 'http://unitsofmeasure.org',
#                                            'unit': 'mg/dL',
#                                            'value': 109}},
#             'search': {'mode': 'match'}},
#            {'fullUrl': 'http://hapi.fhir.org/baseDstu3/Observation/1913162',
#             'resource': {'category': [{'coding': [{'code': 'laboratory',
#                                                    'system': 'http://hl7.org/fhir/observation-category'}]}],
#                          'code': {'coding': [{'code': '2093-3',
#                                               'display': 'Total Cholesterol',
#                                               'system': 'http://loinc.org'}],
#                                   'text': 'Total Cholesterol'},
#                          'context': {'reference': 'Encounter/1913156'},
#                          'effectiveDateTime': '2011-09-12T13:29:49-04:00',
#                          'id': '1913162',
#                          'issued': '2011-09-12T13:29:49-04:00',
#                          'meta': {'lastUpdated': '2019-05-09T10:09:50.460+00:00',
#                                   'profile': ['http://standardhealthrecord.org/fhir/StructureDefinition/shr-observation-Observation'],
#                                   'versionId': '1'},
#                          'resourceType': 'Observation',
#                          'status': 'final',
#                          'subject': {'reference': 'Patient/1913132'},
#                          'valueQuantity': {'code': 'mg/dL',
#                                            'system': 'http://unitsofmeasure.org',
#                                            'unit': 'mg/dL',
#                                            'value': 198}},
#             'search': {'mode': 'match'}},
#            {'fullUrl': 'http://hapi.fhir.org/baseDstu3/Observation/1913161',
#             'resource': {'category': [{'coding': [{'code': 'vital-signs',
#                                                    'system': 'http://hl7.org/fhir/observation-category'}]}],
#                          'code': {'coding': [{'code': '55284-4',
#                                               'display': 'Blood Pressure',
#                                               'system': 'http://loinc.org'}]},
#                          'component': [{'code': {'coding': [{'code': '8480-6',
#                                                              'display': 'Systolic '
#                                                                         'Blood '
#                                                                         'Pressure',
#                                                              'system': 'http://loinc.org'}],
#                                                  'text': 'Systolic Blood '
#                                                          'Pressure'},
#                                         'valueQuantity': {'code': 'mmHg',
#                                                           'system': 'http://unitsofmeasure.org',
#                                                           'unit': 'mmHg',
#                                                           'value': 106}},
#                                        {'code': {'coding': [{'code': '8462-4',
#                                                              'display': 'Diastolic '
#                                                                         'Blood '
#                                                                         'Pressure',
#                                                              'system': 'http://loinc.org'}],
#                                                  'text': 'Diastolic Blood '
#                                                          'Pressure'},
#                                         'valueQuantity': {'code': 'mmHg',
#                                                           'system': 'http://unitsofmeasure.org',
#                                                           'unit': 'mmHg',
#                                                           'value': 80}}],
#                          'context': {'reference': 'Encounter/1913156'},
#                          'effectiveDateTime': '2011-09-12T13:29:49-04:00',
#                          'id': '1913161',
#                          'issued': '2011-09-12T13:29:49-04:00',
#                          'meta': {'lastUpdated': '2019-05-09T10:09:50.460+00:00',
#                                   'profile': ['http://standardhealthrecord.org/fhir/StructureDefinition/shr-observation-Observation',
#                                               'http://standardhealthrecord.org/fhir/StructureDefinition/shr-vital-BloodPressure'],
#                                   'versionId': '1'},
#                          'resourceType': 'Observation',
#                          'status': 'final',
#                          'subject': {'reference': 'Patient/1913132'}},
#             'search': {'mode': 'match'}}],
#  'id': '77f5bd27-846f-4104-a175-78bd0c159f35',
#  'link': [{'relation': 'self',
#            'url': 'http://hapi.fhir.org/baseDstu3/Observation?subject=Patient%2F1913132'},
#           {'relation': 'next',
#            'url': 'http://hapi.fhir.org/baseDstu3?_getpages=77f5bd27-846f-4104-a175-78bd0c159f35&_getpagesoffset=20&_count=20&_pretty=true&_bundletype=searchset'}],
#  'meta': {'lastUpdated': '2019-05-31T00:18:05.550+00:00'},
#  'resourceType': 'Bundle',
#  'total': 53,
#  'type': 'searchset'}

# %% [markdown]
# ## Data Model Use
#
# The client contains data model classes, built using ```fhir-parser```, that handle (de)serialization and allow to work with FHIR data in a Pythonic way.
#
# ### Initialize Data Model

# %%
import fhirclient.models.patient
import fhirclient.models.humanname

data = {'id': 'patient-1'}
patient = fhirclient.models.patient.Patient(data)

print(patient.id)
# Out:
# patient-1

# %%
name = fhirclient.models.humanname.HumanName()
name.given = ['Peter']
name.family = 'Parker'

patient.name = [name]
pprint(patient.as_json())
# Out:
# {'id': 'patient-1',
#  'name': [{'family': 'Parker', 'given': ['Peter']}],
#  'resourceType': 'Patient'}

# %%
name.given = 'Peter'
patient.as_json() # throws FHIRValidationError: because we incorrectly set the name to a string
# Out:
# ---------------------------------------------------------------------------
# FHIRValidationError                       Traceback (most recent call last)
# <ipython-input-22-814c163e63cc> in <module>
#       1 name.given = 'Peter'
# ----> 2 patient.as_json() # throws FHIRValidationError: because we incorrectly set the name to a string
#
# ~/anaconda/envs/cmu3/lib/python3.6/site-packages/fhirclient/models/fhirabstractresource.py in as_json(self)
#      40
#      41     def as_json(self):
# ---> 42         js = super(FHIRAbstractResource, self).as_json()
#      43         js['resourceType'] = self.resource_type
#      44         return js
#
# ~/anaconda/envs/cmu3/lib/python3.6/site-packages/fhirclient/models/fhirabstractbase.py in as_json(self)
#     295
#     296         if len(errs) > 0:
# --> 297             raise FHIRValidationError(errs)
#     298         return js
#     299
#
# FHIRValidationError: {root}:
#   name.0:
#     given:
#       Expecting property "given" on <class 'fhirclient.models.humanname.HumanName'> to be list, but is <class 'str'>

# %% [markdown]
# ### Initialize from JSON file

# %%
import json
import fhirclient.models.patient

with open('patient.json', 'r') as h:
    pjs = json.load(h)
    patient = fhirclient.models.patient.Patient(pjs)
    print(patient.name[0].family)
    print(patient.name[0].given[0])
    print(patient.gender)
    print(patient.birthDate.isostring)
# Out:
# McNutty
# Jimmy
# male
# 1951-02-15
